# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
data_path = '../../data/temporal_unigram_cos_conlen/'

# %%
fandom_list = [l.strip() for l in open('../../data/fandom_filtered_list')]

# %%
df = pd.read_csv(os.path.join(data_path, fandom_list[1] + '_temporal_cos_toprev_conlen.tsv'), sep = '\t')

# %%
df = df.sort_values(by='Kudos',ascending=False)

# %%
df.columns.values
# Out:
# array(['AdditionalTags', 'ArchiveWarnings', 'Author', 'Bookmarks',
#        'Category', 'ChapterIndex', 'Chapters', 'Characters', 'Comments',
#        'CompleteDate', 'Fandoms', 'Hits', 'Kudos', 'Language', 'Notes',
#        'PublishDate', 'Rating', 'Relationship', 'Summary', 'Title', 'URL',
#        'UpdateDate', 'Words', 'Cos'], dtype=object)

# %%
plt.scatter(np.arange(len(df)), df.Cos)

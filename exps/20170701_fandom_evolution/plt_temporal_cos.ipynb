# %%
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import numpy as np

# %%
data_path = '../../data/temporal_unigram_cos/'

# %%
fandom_list = os.listdir(data_path)

# %%
di = pickle.load(open( data_path + 'attack_on_titan.pkl','rb'))
di
# Out:
# {'2013-05_2013-06_2013-07': 0.19426057601116031,
#  '2013-06_2013-07_2013-08': 0.16857036823868093,
#  '2013-07_2013-08_2013-09': 0.17333331975932664,
#  '2013-08_2013-09_2013-10': 0.16285198543952981,
#  '2013-09_2013-10_2013-11': 0.16506276451324478,
#  '2013-10_2013-11_2013-12': 0.16928828401784751,
#  '2013-11_2013-12_2014-01': 0.18814760701584177,
#  '2013-12_2014-01_2014-02': 0.18546300408930746,
#  '2014-01_2014-02_2014-03': 0.16272964533891515,
#  '2014-02_2014-03_2014-04': 0.15759067554611922,
#  '2014-03_2014-04_2014-05': 0.14920499267382131,
#  '2014-04_2014-05_2014-06': 0.17269124948333489,
#  '2014-05_2014-06_2014-07': 0.17751920907302604,
#  '2014-06_2014-07_2014-08': 0.15907309486462576,
#  '2014-07_2014-08_2014-09': 0.17783668388456977,
#  '2014-08_2014-09_2014-10': 0.15269922118829579,
#  '2014-09_2014-10_2014-11': 0.16967302561655428,
#  '2014-10_2014-11_2014-12': 0.17093196782318659,
#  '2014-11_2014-12_2015-01': 0.15970857110720249,
#  '2014-12_2015-01_2015-02': 0.15807251555167384,
#  '2015-01_2015-02_2015-03': 0.15795506110638977,
#  '2015-02_2015-03_2015-04': 0.15131747681050109,
#  '2015-03_2015-04_2015-05': 0.13942496334387891,
#  '2015-04_2015-05_2015-06': 0.16852641632411863,
#  '2015-05_2015-06_2015-07': 0.15876745821758415,
#  '2015-06_2015-07_2015-08': 0.1589909386323175,
#  '2015-07_2015-08_2015-09': 0.16048990530987528,
#  '2015-08_2015-09_2015-10': 0.1740659260730304,
#  '2015-09_2015-10_2015-11': 0.18749686717309605,
#  '2015-10_2015-11_2015-12': 0.15039591464025076,
#  '2015-11_2015-12_2016-01': 0.15578403735126606,
#  '2015-12_2016-01_2016-02': 0.18618681398097878,
#  '2016-01_2016-02_2016-03': 0.14426600898381914,
#  '2016-02_2016-03_2016-04': 0.17360041732179834,
#  '2016-03_2016-04_2016-05': 0.1592399951468764}

# %%
fandom_list
# Out:
# ['arthurian_mythology_&_related_fandoms.pkl',
#  'attack_on_titan.pkl',
#  'bishoujo_senshi_sailor_moon.pkl',
#  'buffy_the_vampire_slayer.pkl',
#  'dcu.pkl',
#  'doctor_who_&_related_fandoms.pkl',
#  'dragon_age_all_media_types.pkl',
#  'haikyuu.pkl',
#  'hamilton_miranda.pkl',
#  'harry_potter.pkl',
#  'hetalia_axis_powers.pkl',
#  'homestuck.pkl',
#  'kuroko_no_basuke.pkl',
#  'les_miserables_all_media_types.pkl',
#  'marvel.pkl',
#  'ms_paint_adventures.pkl',
#  'naruto.pkl',
#  'one_direction.pkl',
#  'shakespare_william_works.pkl',
#  'sherlock_holmes_&_related_fandoms.pkl',
#  'star_wars_all_media_types.pkl',
#  'supernatural.pkl',
#  'the_avengers_all_media_types.pkl',
#  'the_walking_dead_&_related_fandoms.pkl',
#  'tolkien_j_r_r_works_&_related_fandoms.pkl']

# %%
# still on going
# or has a new installment since 2015
list1 = ['arthurian_mythology_&_related_fandoms.pkl',
         'attack_on_titan.pkl',
          'bishoujo_senshi_sailor_moon.pkl',
         'dcu.pkl',
         'doctor_who_&_related_fandoms.pkl',
          'dragon_age_all_media_types.pkl',
         'haikyuu.pkl',
         'homestuck.pkl',
         'kuroko_no_basuke.pkl',
         'marvel.pkl',
         'ms_paint_adventures.pkl',
         'sherlock_holmes_&_related_fandoms.pkl',
         'star_wars_all_media_types.pkl',
         'supernatural.pkl',
         'the_avengers_all_media_types.pkl',
         'the_walking_dead_&_related_fandoms.pkl',
        
        ]

# %%
# ended before 2015
# or single installment
list2 = [ 'buffy_the_vampire_slayer.pkl',
          'hamilton_miranda.pkl',
         'harry_potter.pkl',
        'hetalia_axis_powers.pkl',
         'naruto.pkl',
         'shakespare_william_works.pkl',
          'les_miserables_all_media_types.pkl',
          'one_direction.pkl',

          'tolkien_j_r_r_works_&_related_fandoms.pkl']

# %%
fig, axs = plt.subplots(4,3, figsize=(20, 20))
idx2 = 1
for idx, fandom in enumerate(fandom_list):
    di = pickle.load(open(data_path + fandom, 'rb'))
    label = sorted(di.keys())
    x = range(0, len(label))
    y = [di[k] for k in label]
    
    m,b = np.polyfit(x, y, 1) 
    if m > 0:
        fig.add_subplot(4, 3, idx2)
        idx2 += 1
        plt.plot(x, y, 'yo', x, m*x+b, '--k') 
        plt.title(fandom.replace('.pkl', ''), fontsize=20)
        plt.savefig('3mon_ave_cos_to_center_dec.png', format='png')
# Out:
# /Users/jingy/anaconda/envs/python35/lib/python3.5/site-packages/ipykernel/__main__.py:13: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
fig, axs = plt.subplots(4,4, figsize=(20, 20))
idx2 = 1
for idx, fandom in enumerate(fandom_list):
    di = pickle.load(open(data_path + fandom, 'rb'))
    label = sorted(di.keys())
    x = range(0, len(label))
    y = [di[k] for k in label]
    
    m,b = np.polyfit(x, y, 1) 
    if m <= 0:
        fig.add_subplot(4, 4, idx2)
        idx2 += 1
        plt.plot(x, y, 'yo', x, m*x+b, '--k') 
        plt.title(fandom.replace('.pkl', ''), fontsize=20)
        plt.savefig('3mon_ave_cos_to_center_dec.png', format='png')
# Out:
# /Users/jingy/anaconda/envs/python35/lib/python3.5/site-packages/ipykernel/__main__.py:13: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
def plot_scatter_sq(fandom_list, dic):
    fig, axs = plt.subplots(5,5, figsize=(30, 20))
    axs = axs.ravel()
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.rcParams.update({'axes.titlesize': 'large'})
    
    for i in range(0, len(fandom_list)):
        k = sorted([k for k in dic[fandom_list[i]].keys()])
        x = [i*i for i in k]
        y = [dic[fandom_list[i]][j][0] for j in k]
        
#     Make error bars
        lower_error = [dic[fandom_list[i]][j][0]-dic[fandom_list[i]][j][1] for j in k]
        lower_error = [i*i for i in lower_error]
        upper_error = [dic[fandom_list[i]][j][2]-dic[fandom_list[i]][j][0] for j in k]
        upper_error = [i*i for i in upper_error]
        asymmetric_error = [lower_error, upper_error]

        axs[i].errorbar(x, y, yerr=asymmetric_error,fmt='o')
        axs[i].plot(x, y, 'o-')
        axs[i].set_title(fandom_list[i].replace('_agg_cos.tsv', ''), fontsize = 20)
#         axs[i].set_xlim([min(x) -1, max(x) + 1])
#         axs[i].set_ylim([min(y) -0.2, max(y) + 0.2])
        for tick in axs[i].xaxis.get_major_ticks():
            tick.label.set_fontsize(16) 
        for tick in axs[i].yaxis.get_major_ticks():
            tick.label.set_fontsize(16)
        
        # ax.set_yscale('log')

    fig.text(0.5, 0.06, 'Cosine distance squared', ha='center', va='center', fontsize=25)
    fig.text(0.08, 0.5, 'Log Kudos', ha='center', va='center', rotation='vertical',fontsize=25)
    
    plt.savefig('cos_sq_log_kudos_agg.png', format = 'png')

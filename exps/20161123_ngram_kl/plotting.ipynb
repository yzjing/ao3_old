# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import os

# %%
path = '../../data/unigram_kl/'

# %%
fandom_list = [line.strip() for line in open('../../data/fandom_filtered_list')]

# %%
plt.plot(range(len(d)), [d[i] for i in sorted(d.keys())])
plt.

# %%
fig, axs = plt.subplots(6,6, figsize=(30, 20))
axs = axs.ravel()
for i in range(len(os.listdir(path))):
    d = pickle.load(open(path + fandom_list[i], 'rb'))
    axs[i].plot(range(len(d)), [d[j] for j in sorted(d.keys())])
    axs[i].set_title(fandom_list[i])
#     fig.text(0.5, 0.04, 'Chapters', ha='center', va='center')
#     fig.text(0.06, 0.5, field, ha='center', va='center', rotation='vertical')
#     plt.savefig(field + '_kudos_all.png', format = 'png')

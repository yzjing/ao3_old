# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import random
from scipy import stats

# %%
data_path = '../../data/temporal_kl_kudos/'

# %%
fandom_list_prev = [i for i in os.listdir(data_path) if 'prev' in i]

# %%
fandom_list_futu = [i for i in os.listdir(data_path) if 'futu' in i]

# %%
df_1 = pd.read_csv(os.path.join(data_path, fandom_list_prev[0]), sep = '\t').sort()
# Out:
# /Users/jingy/anaconda/envs/python35/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   if __name__ == '__main__':

# %%
df_1.head()
# Out:
#                                       AdditionalTags  \
# 0                                          Christmas
# 1                      Crossover, Crossover Pairings
# 2  Alternate Universe - Canon, Canon Rewrite, Rei...
# 3  Romance, Bromance, Humor, Angst, Friendship, A...
# 4                                            Songfic
#
#              ArchiveWarnings          Author  Bookmarks Category  \
# 0  No Archive Warnings Apply  Heavenly_Pearl          1      Gen
# 1  No Archive Warnings Apply    Usami_chan13          1   F/MGen
# 2  No Archive Warnings Apply     chrissy_sky          9   M/MF/F
# 3  No Archive Warnings Apply        Satine86          1   F/FF/M
# 4  No Archive Warnings Apply  Heavenly_Pearl          0      Gen
#
#    ChapterIndex  Chapters                                         Characters  \
# 0           NaN         1  Meiou Setsuna | Sailor Pluto, Chibiusa | Sailo...
# 1           9.0         9  Aino Minako | Sailor Venus, Kurama | Minamino ...
# 2           1.0         7  Chiba Mamoru | Tuxedo Kamen, Furuhata Motoki, ...
# 3           1.0        24  Jadeite (Sailor Moon), Hino Rei | Sailor Mars,...
# 4           NaN         1                         Aino Minako | Sailor Venus
#
#    Comments CompleteDate    ...     \
# 0         1   2011-12-15    ...
# 1         1          NaN    ...
# 2         0          NaN    ...
# 3         0   2012-05-31    ...
# 4         0   2012-02-10    ...
#
#                                                Notes  PublishDate  \
# 0  DISCLAIMER: Sailor Moon is the property of Tak...   2011-12-15
# 1                                                NaN   2012-05-28
# 2  We expand heavily on Mamoru\xe2\x80\x99s backg...   2012-01-21
# 3  The "advent drabblender" consisted of a \'door...   2012-05-31
# 4  DISCLAIMER: "Sailor Moon" is the property of T...   2012-02-10
#
#                   Rating                                       Relationship  \
# 0      General Audiences                                                NaN
# 1      General Audiences  Aino Minako | Sailor Venus/Kurama | Minamino S...
# 2                 Mature  Chiba Mamoru | Tuxedo Kamen/Furuhata Motoki, H...
# 3                 Mature  Senshi/Shitennou, Chiba Mamoru | Tuxedo Kamen/...
# 4  Teen And Up Audiences                                                NaN
#
#                                              Summary                    Title  \
# 0    Pluto receives the best Christmas present ever.         Pluto\'s Present
# 1  "A floral symbol sacred to Venus and signifyin...        Of Love and Roses
# 2  Strange things are happening in Tokyo. Mamoru ...   Rebuild of Sailor Moon
# 3  Series of drabbles written for LJ advent drabb...  My True Love Gave To Me
# 4  Minako\'s mother has a secret obsession: a lov...       Queen of Hollywood
#
#                                                  URL  UpdateDate  Words  \
# 0            http://archiveofourown.org/works/294160         NaN   1539
# 1  http://archiveofourown.org/works/415341/chapte...  2012-05-29  45918
# 2  http://archiveofourown.org/works/324625/chapte...  2013-02-12  29093
# 3  http://archiveofourown.org/works/418021/chapte...         NaN   9365
# 4            http://archiveofourown.org/works/336692         NaN   1122
#
#          KL
# 0  0.248874
# 1  0.484904
# 2  0.483941
# 3  0.145661
# 4  0.140982
#
# [5 rows x 24 columns]

# %%
df_2 = pd.read_csv(os.path.join(data_path, fandom_list_futu[0]), sep = '\t').sort()
# Out:
# /Users/jingy/anaconda/envs/python35/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   if __name__ == '__main__':

# %%
df_2.head()
# Out:
#                                       AdditionalTags  \
# 0                                              Humor
# 1                   Swordplay, Community: springkink
# 2                                Community: hc_bingo
# 3                                                NaN
# 4  Romance, Friendship, Reunions, Alternate Unive...
#
#              ArchiveWarnings          Author  Bookmarks Category  \
# 0  No Archive Warnings Apply  Heavenly_Pearl          0      Gen
# 1  No Archive Warnings Apply        kikimaye          1      F/M
# 2  No Archive Warnings Apply      SailorPtah          7      Gen
# 3  No Archive Warnings Apply  Heavenly_Pearl          1      F/M
# 4  No Archive Warnings Apply        Satine86         19      F/M
#
#    ChapterIndex  Chapters                                         Characters  \
# 0           NaN         1  Hino Rei | Sailor Mars, Kotobuki Ran, Yamazaki...
# 1           NaN         1               Kunzite (Sailor Moon), Sailor Senshi
# 2           NaN         1  Kaolinite, Eudial, Mimete, Viluy, Jon Stewart,...
# 3           NaN         1  Meiou Setsuna | Sailor Pluto, Chibiusa | Sailo...
# 4           9.0        11  Tsukino Usagi | Sailor Moon, Chiba Mamoru | Tu...
#
#    Comments CompleteDate    ...     \
# 0         0   2011-11-21    ...
# 1         0   2011-10-11    ...
# 2         4   2011-10-18    ...
# 3         0   2011-12-30    ...
# 4         0   2012-01-16    ...
#
#                                                Notes  PublishDate  \
# 0  DISCLAIMER: "Super GALS" doesn\'t belong to me...   2011-11-21
# 1  Springkink Prompt - "Minako Aino/Kunzite: Swor...   2011-10-11
# 2                                                NaN   2011-10-18
# 3  DISCLAIMER: Sailor Moon is the property of Tak...   2011-12-30
# 4                                                NaN   2012-01-16
#
#                   Rating                                       Relationship  \
# 0      General Audiences                                                NaN
# 1  Teen And Up Audiences                 Kunzite/Aino Minako | Sailor Venus
# 2      General Audiences                                                NaN
# 3      General Audiences                                                NaN
# 4  Teen And Up Audiences  Senshi/Shitennou, Chiba Mamoru | Tuxedo Kamen/...
#
#                                              Summary  \
# 0  After reading about the magic of Hikawa good l...
# 1  Sailor Venus needs to teach the senshi swords ...
# 2  What it says on the tin. Heart crystals that K...
# 3  Hawkseye is known for his taste in older women...
# 4  "It\'s a burden: remembering something that no...
#
#                                                Title  \
# 0                                       Not So Lucky
# 1                              High-Heeled Swordplay
# 2  Five (And Then Some) Heart Crystals The Death ...
# 3                                   Hawk\'s Eye View
# 4                                             Burden
#
#                                                  URL UpdateDate  Words  \
# 0            http://archiveofourown.org/works/281128        NaN   1997
# 1            http://archiveofourown.org/works/974280        NaN   6166
# 2            http://archiveofourown.org/works/266419        NaN   1830
# 3            http://archiveofourown.org/works/307838        NaN  10491
# 4  http://archiveofourown.org/works/288457/chapte...        NaN  31449
#
#          KL
# 0  0.219846
# 1  0.465081
# 2  0.196805
# 3  0.676003
# 4  0.355824
#
# [5 rows x 24 columns]

# %%
df_1.columns.values
# Out:
# array(['AdditionalTags', 'ArchiveWarnings', 'Author', 'Bookmarks',
#        'Category', 'ChapterIndex', 'Chapters', 'Characters', 'Comments',
#        'CompleteDate', 'Fandoms', 'Hits', 'Kudos', 'Language', 'Notes',
#        'PublishDate', 'Rating', 'Relationship', 'Summary', 'Title', 'URL',
#        'UpdateDate', 'Words', 'KL'], dtype=object)

# %%
df = pd.merge(df_1, df_2, on=['AdditionalTags', 'ArchiveWarnings', 'Author', 'Bookmarks',
       'Category', 'ChapterIndex', 'Chapters', 'Characters', 'Comments',
       'CompleteDate', 'Fandoms', 'Hits', 'Kudos', 'Language', 'Notes',
       'PublishDate', 'Rating', 'Relationship', 'Summary', 'Title', 'URL',
       'UpdateDate', 'Words'], how='inner')

# %%
len(df_2)
# Out:
# 1700

# %%
len(df)
# Out:
# 820

# %%
df.head(20)
# Out:
#                                        AdditionalTags  \
# 0                                           Christmas
# 1                                           Christmas
# 2                       Crossover, Crossover Pairings
# 3   Alternate Universe - Canon, Canon Rewrite, Rei...
# 4   Romance, Bromance, Humor, Angst, Friendship, A...
# 5                                             Songfic
# 6   Romance, Bromance, Humor, Angst, Friendship, A...
# 7   Romance, Bromance, Humor, Angst, Friendship, A...
# 8   Romance, Bromance, Humor, Angst, Friendship, A...
# 9   Romance, Bromance, Humor, Angst, Friendship, A...
# 10                                   Parody, Mary Sue
# 11                                   Parody, Mary Sue
# 12                                       Drama, Angst
# 13                                                NaN
# 14                            Drama, Romance, Tragedy
# 15                                              Humor
# 16                                              Humor
# 17                              Romance, Drama, Angst
# 18  Romance, Revisionist Fairy Tale, Alternate Uni...
# 19  Romance, Revisionist Fairy Tale, Alternate Uni...
#
#               ArchiveWarnings          Author  Bookmarks Category  \
# 0   No Archive Warnings Apply  Heavenly_Pearl          1      Gen
# 1   No Archive Warnings Apply  Heavenly_Pearl          1      Gen
# 2   No Archive Warnings Apply    Usami_chan13          1   F/MGen
# 3   No Archive Warnings Apply     chrissy_sky          9   M/MF/F
# 4   No Archive Warnings Apply        Satine86          1   F/FF/M
# 5   No Archive Warnings Apply  Heavenly_Pearl          0      Gen
# 6   No Archive Warnings Apply        Satine86          1   F/FF/M
# 7   No Archive Warnings Apply        Satine86          1   F/FF/M
# 8   No Archive Warnings Apply        Satine86          1   F/FF/M
# 9   No Archive Warnings Apply        Satine86          1   F/FF/M
# 10  No Archive Warnings Apply  Heavenly_Pearl          0      F/M
# 11  No Archive Warnings Apply  Heavenly_Pearl          0      F/M
# 12      Major Character Death  Heavenly_Pearl          2      F/M
# 13  No Archive Warnings Apply         hariboo          1      F/M
# 14      Major Character Death  Heavenly_Pearl          0      F/M
# 15  No Archive Warnings Apply  Heavenly_Pearl          0      F/M
# 16  No Archive Warnings Apply  Heavenly_Pearl          0      F/M
# 17                   Underage  Heavenly_Pearl          3      F/M
# 18  No Archive Warnings Apply  Heavenly_Pearl          0      F/M
# 19  No Archive Warnings Apply  Heavenly_Pearl          0      F/M
#
#     ChapterIndex  Chapters                                         Characters  \
# 0            NaN         1  Meiou Setsuna | Sailor Pluto, Chibiusa | Sailo...
# 1            NaN         1  Meiou Setsuna | Sailor Pluto, Chibiusa | Sailo...
# 2            9.0         9  Aino Minako | Sailor Venus, Kurama | Minamino ...
# 3            1.0         7  Chiba Mamoru | Tuxedo Kamen, Furuhata Motoki, ...
# 4            1.0        24  Jadeite (Sailor Moon), Hino Rei | Sailor Mars,...
# 5            NaN         1                         Aino Minako | Sailor Venus
# 6           17.0        24  Jadeite (Sailor Moon), Hino Rei | Sailor Mars,...
# 7           17.0        24  Jadeite (Sailor Moon), Hino Rei | Sailor Mars,...
# 8           17.0        24  Jadeite (Sailor Moon), Hino Rei | Sailor Mars,...
# 9           17.0        24  Jadeite (Sailor Moon), Hino Rei | Sailor Mars,...
# 10           NaN         1  Tsukino Usagi | Sailor Moon, Chiba Mamoru | Tu...
# 11           NaN         1  Tsukino Usagi | Sailor Moon, Chiba Mamoru | Tu...
# 12          17.0        18  Hino Rei | Sailor Mars, Hino Rei\'s Grandpa, P...
# 13           NaN         1                                                NaN
# 14           NaN         1  Chibiusa | Sailor Chibi Moon, Helios (Sailor M...
# 15           NaN         1  Chibiusa | Sailor Chibi Moon, CereCere | Sailo...
# 16           NaN         1  Chibiusa | Sailor Chibi Moon, CereCere | Sailo...
# 17           NaN         1  Kou Seiya | Sailor Star Fighter, Tsukino Usagi...
# 18           NaN         1  Chibiusa | Sailor Chibi Moon, Queen Nehellenia...
# 19           NaN         1  Chibiusa | Sailor Chibi Moon, Queen Nehellenia...
#
#     Comments CompleteDate    ...    PublishDate                 Rating  \
# 0          1   2011-12-15    ...     2011-12-15      General Audiences
# 1          1   2011-12-15    ...     2011-12-15      General Audiences
# 2          1          NaN    ...     2012-05-28      General Audiences
# 3          0          NaN    ...     2012-01-21                 Mature
# 4          0   2012-05-31    ...     2012-05-31                 Mature
# 5          0   2012-02-10    ...     2012-02-10  Teen And Up Audiences
# 6          0   2012-05-31    ...     2012-05-31                 Mature
# 7          0   2012-05-31    ...     2012-05-31                 Mature
# 8          0   2012-05-31    ...     2012-05-31                 Mature
# 9          0   2012-05-31    ...     2012-05-31                 Mature
# 10         0   2012-04-09    ...     2012-04-09      General Audiences
# 11         0   2012-04-09    ...     2012-04-09      General Audiences
# 12         0   2012-05-04    ...     2012-05-03  Teen And Up Audiences
# 13         0   2011-12-12    ...     2011-12-12      General Audiences
# 14         0   2012-02-24    ...     2012-02-24      General Audiences
# 15         3   2012-03-12    ...     2012-03-12      General Audiences
# 16         3   2012-03-12    ...     2012-03-12      General Audiences
# 17         0   2012-04-10    ...     2012-04-10                 Mature
# 18         1   2012-04-09    ...     2012-04-09      General Audiences
# 19         1   2012-04-09    ...     2012-04-09      General Audiences
#
#                                          Relationship  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Aino Minako | Sailor Venus/Kurama | Minamino S...
# 3   Chiba Mamoru | Tuxedo Kamen/Furuhata Motoki, H...
# 4   Senshi/Shitennou, Chiba Mamoru | Tuxedo Kamen/...
# 5                                                 NaN
# 6   Senshi/Shitennou, Chiba Mamoru | Tuxedo Kamen/...
# 7   Senshi/Shitennou, Chiba Mamoru | Tuxedo Kamen/...
# 8   Senshi/Shitennou, Chiba Mamoru | Tuxedo Kamen/...
# 9   Senshi/Shitennou, Chiba Mamoru | Tuxedo Kamen/...
# 10  Chiba Mamoru | Tuxedo Kamen/Tsukino Usagi | Sa...
# 11  Chiba Mamoru | Tuxedo Kamen/Tsukino Usagi | Sa...
# 12                      Hino Rei | Sailor Mars/Kaidou
# 13                     Hino Rei | Sailor Mars/Jadeite
# 14                Chibiusa | Sailor Chibi Moon/Helios
# 15                Chibiusa | Sailor Chibi Moon/Helios
# 16                Chibiusa | Sailor Chibi Moon/Helios
# 17  Kou Seiya | Sailor Star Fighter/Tsukino Usagi ...
# 18  Chibiusa | Sailor Chibi Moon/Helios, King Endy...
# 19  Chibiusa | Sailor Chibi Moon/Helios, King Endy...
#
#                                               Summary  \
# 0     Pluto receives the best Christmas present ever.
# 1     Pluto receives the best Christmas present ever.
# 2   "A floral symbol sacred to Venus and signifyin...
# 3   Strange things are happening in Tokyo. Mamoru ...
# 4   Series of drabbles written for LJ advent drabb...
# 5   Minako\'s mother has a secret obsession: a lov...
# 6   Series of drabbles written for LJ advent drabb...
# 7   Series of drabbles written for LJ advent drabb...
# 8   Series of drabbles written for LJ advent drabb...
# 9   Series of drabbles written for LJ advent drabb...
# 10  When a new student from America transfers into...
# 11  When a new student from America transfers into...
# 12  Hino Keitaro didn\'t believe in love until he ...
# 13  rei has visitor and it\'s snowing on christmas...
# 14  Helios watches his beloved maiden die from a d...
# 15  Princess Lady Serenity decides to make a drast...
# 16  Princess Lady Serenity decides to make a drast...
# 17  When Seiya spends the night at Usagi\'s house ...
# 18  Small Lady runs away and joins a circus when h...
# 19  Small Lady runs away and joins a circus when h...
#
#                                Title  \
# 0                   Pluto\'s Present
# 1                   Pluto\'s Present
# 2                  Of Love and Roses
# 3             Rebuild of Sailor Moon
# 4            My True Love Gave To Me
# 5                 Queen of Hollywood
# 6            My True Love Gave To Me
# 7            My True Love Gave To Me
# 8            My True Love Gave To Me
# 9            My True Love Gave To Me
# 10       Blast From A Forgotten Past
# 11       Blast From A Forgotten Past
# 12                    Spirit of Fire
# 13        frost nipping at your nose
# 14                         Red Death
# 15                        Snip, Snip
# 16                        Snip, Snip
# 17                       Realization
# 18  Small Lady and the Seven Amazons
# 19  Small Lady and the Seven Amazons
#
#                                                   URL  UpdateDate   Words  \
# 0             http://archiveofourown.org/works/294160         NaN    1539
# 1             http://archiveofourown.org/works/294160         NaN    1539
# 2   http://archiveofourown.org/works/415341/chapte...  2012-05-29   45918
# 3   http://archiveofourown.org/works/324625/chapte...  2013-02-12   29093
# 4   http://archiveofourown.org/works/418021/chapte...         NaN    9365
# 5             http://archiveofourown.org/works/336692         NaN    1122
# 6   http://archiveofourown.org/works/418021/chapte...         NaN    9365
# 7   http://archiveofourown.org/works/418021/chapte...         NaN    9365
# 8   http://archiveofourown.org/works/418021/chapte...         NaN    9365
# 9   http://archiveofourown.org/works/418021/chapte...         NaN    9365
# 10            http://archiveofourown.org/works/379465         NaN    1986
# 11            http://archiveofourown.org/works/379465         NaN    1986
# 12  http://archiveofourown.org/works/381677/chapte...         NaN  257691
# 13            http://archiveofourown.org/works/332835         NaN    1195
# 14            http://archiveofourown.org/works/346217         NaN    1438
# 15            http://archiveofourown.org/works/361081         NaN    1042
# 16            http://archiveofourown.org/works/361081         NaN    1042
# 17  http://archiveofourown.org/works/380141?view_a...         NaN    3198
# 18            http://archiveofourown.org/works/379547         NaN     999
# 19            http://archiveofourown.org/works/379547         NaN     999
#
#         KL_x      KL_y
# 0   0.248874  0.224724
# 1   0.248874  0.245591
# 2   0.484904  0.480290
# 3   0.483941  0.449275
# 4   0.145661  0.146550
# 5   0.140982  0.122798
# 6   0.082601  0.078195
# 7   0.082601  0.061306
# 8   0.074457  0.078195
# 9   0.074457  0.061306
# 10  0.301102  0.242633
# 11  0.305043  0.242633
# 12  0.904931  0.705317
# 13  0.167676  0.157042
# 14  0.223421  0.204682
# 15  0.173000  0.171385
# 16  0.164578  0.171385
# 17  0.375375  0.372585
# 18  0.162449  0.157656
# 19  0.162449  0.110835
#
# [20 rows x 25 columns]

# %%
df = df.dropna(subset=['KL_x', 'KL_y', 'Kudos'])
x = abs(df['KL_x'] - df['KL_y'])
y = df['Kudos']
stats.pearsonr(x,y)
# Out:
# (-0.047963721144113271, 0.17532909016158232)

# %%
for i,fandom in enumerate(fandom_list_futu):
    df = pd.read_csv(os.path.join(data_path, fandom_list_futu[i]), sep = '\t')
    df = df[df.Chapters == 1]
    print(fandom, len(df))
    df = df.dropna(subset=['KL', 'Words'])
    x = df['KL']
    y = df['Words']
    print(stats.pearsonr(x,y))
# Out:
# bishoujo_senshi_sailor_moon_temporal_kl_tofutu.tsv 377
# (0.90892317229494801, 1.5584050517644008e-144)
# haikyuu_temporal_kl_tofutu.tsv 337
# (0.83323183842015247, 3.2406059422021306e-88)
# hamilton_miranda_temporal_kl_tofutu.tsv 32
# (0.94157721251223503, 1.0121353008209084e-15)
# hetalia_axis_powers_temporal_kl_tofutu.tsv 998
# (0.82298811068080491, 7.2889516549569029e-247)
# homestuck_temporal_kl_tofutu.tsv 781
# (0.83780826222549709, 6.0781081827788594e-207)
# kuroko_no_basuke_temporal_kl_tofutu.tsv 589
# (0.92019683804971975, 2.8727563531053383e-241)
# les_miserables_all_media_types_temporal_kl_tofutu.tsv 538
# (0.8620828417864288, 2.3920129468480309e-160)
# shakespare_william_works_temporal_kl_tofutu.tsv 622
# (0.83888460766631001, 6.3964903189172436e-166)
# the_walking_dead_&_related_fandoms_temporal_kl_tofutu.tsv 293
# (0.89281800453934601, 8.3281289651931107e-103)

# %%
d = dict(zip(df.KL, np.log(df.Kudos)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-2f85d56a2f5a> in <module>()
# ----> 1 d = dict(zip(df.KL, np.log(df.Kudos)))
#
# /Users/jingy/anaconda/envs/python35/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'KL'

# %%
x = [i for i in sorted(d.keys())]
y = [d[i] for i in sorted(d.keys())]

# %%
plt.scatter(x, y)

# %%
def bootstrap_resample(li):
    if len(li) > 0:
        ave_original = np.average(li)
        aves = []
        for i in range(1000):
            sample = []
            for i in range(len(li)):
                sample.append(random.choice(li))
            aves.append(np.average(sample))
        tail = sorted(aves)[24]
        head = sorted(aves)[975]
        return (ave_original, tail, head)

# %%
def create_normed_dfs(df):
    
    # Normalize effects of authors by turning kudos into z-score corresponding to works from this author
    # Seems not useful b/c many authors only have 1 work
#     author_list = df.Author.drop_duplicates().tolist()
#     combined = []
#     for author in author_list:
#         df_a = df[df.Author == author]
#         if len(df_a) > 1:
#             df_a['Kudos'] = (df_a['Kudos'] - df_a['Kudos'].mean())/df_a['Kudos'].std(ddof=0)
#             combined.append(df_a)        
#     df = pd.concat(combined)
#     df = df[df.Kudos != 0]

# #     Normalize by creating hits/kudos 
#     df = df[df.Hits != 0]
#     df = df[df.Kudos != 0]
#     df['Kudos/Hits'] = df['Kudos'].astype(float)/df['Hits'].astype(float)
    
#     Normalize by log scale
    df = df[df.Kudos != 0]
    df['Kudos'] = np.log(df['Kudos'])
    df = df[df.Hits != 0]
    df['Hits'] = np.log(df['Hits'])
    df['Kudos/Hits'] = df['Kudos'] - df['Hits']

#     # filter 0s
# #     df = df.fillna(0)"

#     # turn into z scores
#     df['Cos'] = df['Cos'].astype(float)
#     df['Cos'] = (df['Cos'] - df['Cos'].mean())/df['Cos'].std(ddof=0)

    return df

# %% [markdown]
# ### Plot with bins

# %%
def create_dict(fandom, field, binsize):
    
    df = pd.read_csv(os.path.join(data_path,fandom), sep = '\t', error_bad_lines=False)
    df = df.dropna(subset = [field])
    df = create_normed_dfs(df)
    # Make bins
    df.KL = df.KL.astype(float)
    min_kl = min(df.KL.tolist()) - 0.1
    max_kl = max(df.KL.tolist()) + 0.1
    dic = {}
    for i in np.arange(min_kl, max_kl, binsize):
        df_s = df[(df.KL >= i) & (df.KL < i+binsize)]
        if len(df_s) > 9:
#             print (min_cos, max_cos)
#             print(df_s[field].tolist())
            dic[i] = bootstrap_resample(df_s[field].tolist())
    return dic

# %%
def plot_scatter(fandom_list):
    fig, axs = plt.subplots(5,5, figsize=(30, 20))
    axs = axs.ravel()
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.rcParams.update({'axes.titlesize': 'large'})
    
    for i,fandom in enumerate(fandom_list):
        try:
            dic = create_dict(fandom, 'Kudos', 0.1)
            x = sorted(dic.keys())
            y = [dic[j][0] for j in x]
    #         print(x,y)

    #     Make error bars
            lower_error = [dic[j][0]-dic[j][1] for j in x]
            upper_error = [dic[j][2]-dic[j][0] for j in x]
            asymmetric_error = [lower_error, upper_error]

            axs[i].errorbar(x, y, yerr=asymmetric_error,fmt='o')
            axs[i].plot(x, y, 'o-')
            title = fandom.replace('_temporal_cos_toprev.tsv', '').replace('all_media_types', '')\
            .replace("&_related_fandoms", '').replace("_", ' ').capitalize().replace('Dcu', 'DCU')
            axs[i].set_title(title, fontsize = 20)
    #         axs[i].set_xlim([min(x) -1, max(x) + 1])
    #         axs[i].set_ylim([min(y) -0.2, max(y) + 0.2])
            for tick in axs[i].xaxis.get_major_ticks():
                tick.label.set_fontsize(16) 
            for tick in axs[i].yaxis.get_major_ticks():
                tick.label.set_fontsize(16)

    #         break
            # ax.set_yscale('log')

            fig.text(0.5, 0.06, 'Cosine distance', ha='center', va='center', fontsize=25)
            fig.text(0.08, 0.5, 'Log Kudos', ha='center', va='center', rotation='vertical',fontsize=25)

        except:
            pass
#     plt.savefig('cos_log_kudos_toprev.pdf', format = 'pdf')

# %%
plot_scatter(fandom_list_prev)

# %%
plot_scatter(fandom_list_futu)
